# %%
import numpy as np
import pandas as pd

import seaborn as sns 
import matplotlib.pyplot as plt

# %%
import pandas as pd

# Try with a different encoding like 'ISO-8859-1' or 'windows-1252'
df = pd.read_csv(r'C:\Users\Sahan\Documents\Phase_4_Project\CSV\hotels.csv', encoding='ISO-8859-1')

# Or try with 'windows-1252' encoding
# df = pd.read_csv(r'C:\Users\Sahan\Documents\Phase_4_Project\CSV\hotels.csv', encoding='windows-1252')

# Check the dataframe
print(df.head())
# Out:
#   countyCode  countyName   cityCode  cityName   HotelCode       HotelName  \
# 0         AL     Albania     106078  Albanien     1003300  De Paris Hotel
# 1         AL     Albania     106078  Albanien     1003301     Hotel Green
# 2         AL     Albania     106078  Albanien     1003302  Theranda Hotel
# 3         AL     Albania     106078  Albanien     1003303     Seven Hotel
# 4         AL     Albania     106078  Albanien     1003325        Viktoria
#
#    HotelRating                                            Address  \
# 0     FourStar                  Nr. 7 Brigada Viii Street Tirane
# 1     FourStar  Rruga Kavajes. Kombinat Km 2. Vaqarr VaqarrTir...
# 2    ThreeStar  Rr. Andon Zako Cajupi Villa 6 & 7 Villa 6 & 7T...
# 3    ThreeStar       KAVAJA STREET, CLOSE TURKISH AMBASSY TIRANA
# 4    ThreeStar            Rruga E Elbasanit Km 4 Sauk SaukTirana
#
#                             Attractions  \
# 0                                   NaN
# 1                                   NaN
# ...

# %%
df
# Out:
#         countyCode  countyName   cityCode        cityName   HotelCode  \
# 0               AL     Albania     106078        Albanien     1003300
# 1               AL     Albania     106078        Albanien     1003301
# 2               AL     Albania     106078        Albanien     1003302
# 3               AL     Albania     106078        Albanien     1003303
# 4               AL     Albania     106078        Albanien     1003325
# ...            ...         ...        ...             ...         ...
# 1010028         ZW    Zimbabwe     141497  Victoria Falls     5909458
# 1010029         ZW    Zimbabwe     141497  Victoria Falls     6008100
# 1010030         ZW    Zimbabwe     141497  Victoria Falls     6053177
# 1010031         ZW    Zimbabwe     141497  Victoria Falls     6092731
# 1010032         ZW    Zimbabwe     141497  Victoria Falls     6105635
#
#                                  HotelName  HotelRating  \
# 0                           De Paris Hotel     FourStar
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1010033 entries, 0 to 1010032
# Data columns (total 16 columns):
#  #   Column            Non-Null Count    Dtype
# ---  ------            --------------    -----
#  0   countyCode        1009121 non-null  object
#  1    countyName       1010033 non-null  object
#  2    cityCode         1010033 non-null  int64
#  3    cityName         1010033 non-null  object
#  4    HotelCode        1010033 non-null  int64
#  5    HotelName        1010033 non-null  object
#  6    HotelRating      1010033 non-null  object
#  7    Address          1009931 non-null  object
#  8    Attractions      484941 non-null   object
#  9    Description      963028 non-null   object
#  10   FaxNumber        449686 non-null   object
#  11   HotelFacilities  959655 non-null   object
#  12   Map              1009103 non-null  object
#  13   PhoneNumber      682896 non-null   object
#  14   PinCode          979054 non-null   object
# ...

# %%
# Assuming your DataFrame is named `df`
us_hotels = df[df['countyCode'] == 'US']

# View the first few rows to confirm
us_hotels
# Out:
#         countyCode     countyName   cityCode                     cityName  \
# 866143          US  United States     100328       Abbeville,   Louisiana
# 866144          US  United States     100328       Abbeville,   Louisiana
# 866145          US  United States     100328       Abbeville,   Louisiana
# 866146          US  United States     100328       Abbeville,   Louisiana
# 866147          US  United States     100328       Abbeville,   Louisiana
# ...            ...            ...        ...                          ...
# 1006006         US  United States     143364             Zion,   Illinois
# 1006007         US  United States     143364             Zion,   Illinois
# 1006008         US  United States     142951  Zion Crossroads,   Virginia
# 1006009         US  United States     143934   Zion National Park,   Utah
# 1006010         US  United States     142509        Zumbrota,   Minnesota
#
#           HotelCode                                  HotelName  HotelRating  \
# ...

# %%
us_hotels.to_csv('us_hotels.csv', index=False)

# %%
#Preprocess your data (missing values, outliers, encoding, standardization).
#Perform EDA to understand your features and target variable.
#Apply clustering algorithms (Hierarchical, K-Means, DBSCAN) to identify patterns in the data.
#Reduce dimensionality using PCA if necessary.
#Build a content-based recommendation system based on property similarity.
